# %%
# !ls
# Out:
# cmudict-0.7b  getPhoneme.ipynb	heteronyms  vi-new-lexicon.txt	vnIPA.dict

# %%
with open("vnIPA.dict", "r") as f:
    data = f.readlines()

# %%
data[0].split("  ")
# Out:
# ['a', 'a 1 \n']

# %%
phonemes = list([])
for d in data:
    d = d.rstrip()
    words, phones = d.split('  ')
    phones_set = phones.split(' ')
    print(phones_set)
    phonemes.extend(phones_set)
# Out:
# ['a', '1']
# ['a', '5']
# ['a', '2']
# ['a', '3']
# ['a', '4']
# ['a', '6']
# ['a', 'k', '5']
# ['ă', 'k', '5']
# ['ă', 'k', '6']
# ['ɤ̆', 'k', '6']
# ['a', 'k', '6']
# ['a', 'tʃ', '5']
# ['a', 'tʃ', '6']
# ['a', 'j', '1']
# ['a', 'j', '5']
# ['a', 'j', '4']
# ['a', 'm', '1']
# ['a', 'm', '5']
# ['ă', 'm', '1']
# ['ă', 'm', '3']
# ['ɤ̆', 'm', '1']
# ['ɤ̆', 'm', '5']
# ['ɤ̆', 'm', '2']
# ['ɤ̆', 'm', '4']
# ['ɤ̆', 'm', '6']
# ['a', 'm', '4']
# ['a', 'n', '1']
# ['a', 'n', '5']
# ['ă', 'n', '1']
# ['ɤ̆', 'n', '1']
# ['ɤ̆', 'n', '5']
# ['ɤ̆', 'n', '4']
# ['a', 'ŋ', '1']
# ['a', 'ŋ', '5']
# ['ă', 'ŋ', '1']
# ['ă', 'ŋ', '5']
# ['ă', 'ŋ', '2']
# ['ă', 'ŋ', '4']
# ['ɤ̆', 'ŋ', '2']
# ['a', 'ŋ', '4']
# ['ɛ', 'ɲ', '1']
# ['ɛ', 'ɲ', '5']
# ['ɛ', 'ɲ', '2']
# ['ɛ', 'ɲ', '4']
# ['a', 'w', '1']
# ['a', 'w', '5']
# ['a', 'w', '2']
# ['a', 'w', '4']
# ['a', 'p', '5']
# ['ă', 'p', '5']
# ['ɤ̆', 'p', '5']
# ['ɤ̆', 'p', '6']
# ['a', 't', '5']
# ['ă', 't', '5']
# ['ɤ̆', 't', '5']
# ['a', 't', '6']
# ...

# %%
phonemes = list(set(phonemes))
print(phonemes)
# Out:
# ['ɪ', '6', 'm', 'ă', 'iə', 'ɤ', 'k͡p', 'ʷe', 'ʐw', 'fw', 'hw', 'tʃ', 'bw', 'ʷɤ̆', "'", 't', 'u', 'ʷi', '2', 'r', 'v', 'jw', 'g', 'ɛ', 'ɛ_1', 'ə', 'ɯ', 'cw', 'ɛu', 'ʈ', 'd', 'ʤ', 'l_ɔ_ŋ͡m_1', 'j', 'tʰw', 'ɲw', '5', 'ʐ', 'ʂ', 'ɣw', 'ɔ', 'ʒ', 'ŋw', 'eo', 'sw', 'ʧ', 'p', 'vw', 'ŋ', 'ɣ', 'ʷă', 'o', 'ʷɛ', 'i', 'zw', '4', 'tw', 'mw', '3', 's', 'f', '1', 'ʃ', 'ɲ', 'æ', 'ʂw', 'ɯə', 'h', 'b', 'k', 'dw', 'ʈw', 'c', 'a', 'ʷiu', 'ʷiə', 'l', 'w', 'θ', 'ʌ', 'xw', 'uə', 'ʊ', 'e', 'nw', 'ð', 'n', 'lw', 'tʰ', 'kw', 'x', 'ŋ͡m', 'z', 'ʂ_ɔ_1', 'iɛ', 'ʷa', 'ɤ̆']

# %%
len(phonemes)
# Out:
# 97
